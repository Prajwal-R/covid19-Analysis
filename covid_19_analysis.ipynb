# %% [markdown]
# ## Data Source

# %% [markdown]
# https://api.covid19india.org/
# https://api.covid19india.org/csv/

# %% [markdown]
# ## Import libraries

# %%
# to get web contents
import requests
# to parse json contents
import json
# to parse csv files
import csv

# for numerical operations
import numpy as np
# to store and analysis data in dataframes
import pandas as pd

# %% [markdown]
# ## Raw data

# %%
# read data
raw_1 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data1.csv')
raw_2 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data2.csv')
raw_3 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data3.csv')
raw_4 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data4.csv')
raw_5 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data5.csv')
raw_6 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data6.csv')
raw_7 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data7.csv')
raw_8 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data8.csv')
raw_9 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data9.csv')
raw_10 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data10.csv')
raw_11 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data11.csv')
raw_12 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data12.csv')
raw_13 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data13.csv')
raw_14 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data14.csv')
raw_15 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data15.csv')
raw_16 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data16.csv')

# concatenate dfs
full_data = pd.concat([raw_1, raw_2, raw_3, raw_4, raw_5, 
                       raw_6, raw_7, raw_8, raw_9, raw_10, 
                       raw_11, raw_12, raw_13, raw_14, raw_15, raw_16])

# save to csv`
full_data.to_csv('patients_data.csv', index=False)

# no. of rows and column
print(full_data.shape)

# first few rows
full_data.head(10)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# (353033, 22)
#   Age Bracket                                Backup Notes  \
# 0          20                          Student from Wuhan
# 1         NaN                          Student from Wuhan
# 2         NaN                          Student from Wuhan
# 3          45         Travel history to Italy and Austria
# 4          24  Travel history to Dubai, Singapore contact
# 5          69                             Italian tourist
# 6          55                             Italian tourist
# 7          55                             Italian tourist
# 8          55                             Italian tourist
# 9          55                             Italian tourist
#
#   Contracted from which Patient (Suspected) Current Status Date Announced  \
# 0                                       NaN      Recovered     30/01/2020
# 1                                       NaN      Recovered     02/02/2020
# 2                                       NaN      Recovered     03/02/2020
# 3                                       NaN      Recovered     02/03/2020
# 4                                       NaN      Recovered     02/03/2020
# 5                                       NaN      Recovered     03/03/2020
# 6                                        P6      Recovered     04/03/2020
# 7                                        P6      Recovered     04/03/2020
# 8                                        P6      Recovered     04/03/2020
# 9                                        P6      Recovered     04/03/2020
#
#               Detected City Detected District Detected State  Entry_ID  \
# 0                  Thrissur          Thrissur         Kerala       NaN
# 1                 Alappuzha         Alappuzha         Kerala       NaN
# 2                 Kasaragod         Kasaragod         Kerala       NaN
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi       NaN
# 4                 Hyderabad         Hyderabad      Telangana       NaN
# 5                    Jaipur          Italians      Rajasthan       NaN
# 6                  Gurugram          Italians        Haryana       NaN
# 7                  Gurugram          Italians        Haryana       NaN
# 8                  Gurugram          Italians        Haryana       NaN
# 9                  Gurugram          Italians        Haryana       NaN
#
#    Estimated Onset Date  ...  \
# 0                   NaN  ...
# 1                   NaN  ...
# 2                   NaN  ...
# 3                   NaN  ...
# 4                   NaN  ...
# 5                   NaN  ...
# 6                   NaN  ...
# 7                   NaN  ...
# 8                   NaN  ...
# 9                   NaN  ...
#
#                                                Notes Num Cases Patient Number  \
# 0                               Travelled from Wuhan       1.0            1.0
# 1                               Travelled from Wuhan       1.0            2.0
# 2                               Travelled from Wuhan       1.0            3.0
# 3                      Travelled from Austria, Italy       1.0            4.0
# 4  Travelled from Dubai to Bangalore on 20th Feb,...       1.0            5.0
# 5                               Travelled from Italy       1.0            6.0
# 6                               Travelled from Italy       1.0            7.0
# 7                               Travelled from Italy       1.0            8.0
# 8                               Travelled from Italy       1.0            9.0
# 9                               Travelled from Italy       1.0           10.0
#
#                                             Source_1  \
# 0  https://twitter.com/vijayanpinarayi/status/122...
# 1  https://www.indiatoday.in/india/story/kerala-r...
# 2  https://www.indiatoday.in/india/story/kerala-n...
# 3  https://www.indiatoday.in/india/story/not-a-ja...
# 4  https://www.deccanherald.com/national/south/qu...
# 5  https://indianexpress.com/article/india/corona...
# 6  https://indianexpress.com/article/india/corona...
# 7  https://indianexpress.com/article/india/corona...
# 8  https://indianexpress.com/article/india/corona...
# 9  https://indianexpress.com/article/india/corona...
#
#                                             Source_2  \
# 0  https://weather.com/en-IN/india/news/news/2020...
# 1  https://weather.com/en-IN/india/news/news/2020...
# 2  https://twitter.com/ANI/status/122422148580539...
# 3  https://economictimes.indiatimes.com/news/poli...
# 4  https://www.indiatoday.in/india/story/coronavi...
# 5  https://economictimes.indiatimes.com/news/poli...
# 6  https://www.indiatoday.in/india/story/coronavi...
# 7  https://www.indiatoday.in/india/story/coronavi...
# 8  https://www.indiatoday.in/india/story/coronavi...
# 9  https://www.indiatoday.in/india/story/coronavi...
#
#                                             Source_3 State Patient Number  \
# 0                                                NaN             KL-TS-P1
# 1                                                NaN             KL-AL-P1
# 2  https://weather.com/en-IN/india/news/news/2020...             KL-KS-P1
# 3                                                NaN                DL-P1
# 4  https://www.thehindu.com/news/national/coronav...                TS-P1
# 5  https://twitter.com/PTI_News/status/1240878975...                  NaN
# 6                                                NaN                  NaN
# 7                                                NaN                  NaN
# 8                                                NaN                  NaN
# 9                                                NaN                  NaN
#
#   State code Status Change Date Type of transmission
# 0         KL         14/02/2020             Imported
# 1         KL         14/02/2020             Imported
# 2         KL         14/02/2020             Imported
# 3         DL         15/03/2020             Imported
# 4         TG         02/03/2020             Imported
# 5         RJ         03/03/2020             Imported
# 6         HR         29/03/2020             Imported
# 7         HR         29/03/2020             Imported
# 8         HR         29/03/2020             Imported
# 9         HR         29/03/2020             Imported
#
# [10 rows x 22 columns]

# %%
full_data.drop(["Source_1","Source_2","Source_3","State Patient Number","Contracted from which Patient (Suspected)","Backup Notes","Entry_ID","Type of transmission"],axis=1,inplace=True)

# %%
full_data.head()
# Out:
#   Age Bracket Current Status Date Announced             Detected City  \
# 0          20      Recovered     30/01/2020                  Thrissur
# 1         NaN      Recovered     02/02/2020                 Alappuzha
# 2         NaN      Recovered     03/02/2020                 Kasaragod
# 3          45      Recovered     02/03/2020  East Delhi (Mayur Vihar)
# 4          24      Recovered     02/03/2020                 Hyderabad
#
#   Detected District Detected State  Estimated Onset Date Gender Nationality  \
# 0          Thrissur         Kerala                   NaN      F       India
# 1         Alappuzha         Kerala                   NaN    NaN       India
# 2         Kasaragod         Kerala                   NaN    NaN       India
# 3        East Delhi          Delhi                   NaN      M       India
# 4         Hyderabad      Telangana                   NaN      M       India
#
#                                                Notes  Num Cases  \
# 0                               Travelled from Wuhan        1.0
# 1                               Travelled from Wuhan        1.0
# 2                               Travelled from Wuhan        1.0
# 3                      Travelled from Austria, Italy        1.0
# 4  Travelled from Dubai to Bangalore on 20th Feb,...        1.0
#
#    Patient Number State code Status Change Date
# 0             1.0         KL         14/02/2020
# 1             2.0         KL         14/02/2020
# 2             3.0         KL         14/02/2020
# 3             4.0         DL         15/03/2020
# 4             5.0         TG         02/03/2020

# %% [markdown]
# ## 1. Daily cases in India(from last 5 days)

# %%
# read data
day_wise = pd.read_csv('https://api.covid19india.org/csv/latest/case_time_series.csv')

# save as a .csv file
day_wise.to_csv('nation_level_daily.csv', index=False)

# last 5 rows
day_wise.tail()
# Out:
#             Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 256  12 October             54261          7173570            78365
# 257  13 October             63717          7237287            74079
# 258  14 October             67811          7305098            81582
# 259  15 October             63441          7368539            70792
# 260  16 October             62302          7430841            70568
#
#      Total Recovered  Daily Deceased  Total Deceased
# 256          6224767             710          109308
# 257          6298846             727          110035
# 258          6380428             690          110725
# 259          6451220             882          111607
# 260          6521788             840          112447

# %% [markdown]
# ## 2. Total active case

# %%
df=day_wise
confirmed=df["Total Confirmed"]
Recovered=df["Total Recovered"]
Deceased=df["Total Deceased"]
#df.rename(columns={"": "Confirmed", "Recovered":"","Total Deceased":"Deceased"})
#df['active case'] = df.apply(
for x in range(len(confirmed)): 
    active_case=confirmed[x]-Recovered[x]-Deceased[x]
#df.tail(1)
df["Active_case"]=active_case
df[["Date","Active_case"]].tail(1)
# Out:
#             Date  Active_case
# 260  16 October        796606

# %% [markdown]
# ## 3. Recovery rate

# %%
recovery =round(Recovered/confirmed*100, 2)
recovery_rate= list(map("{}%".format, recovery))

df['recovery_rate']=recovery_rate
df[["Date","Total Confirmed","recovery_rate"]].tail()
# Out:
#             Date  Total Confirmed recovery_rate
# 256  12 October           7173570        86.77%
# 257  13 October           7237287        87.03%
# 258  14 October           7305098        87.34%
# 259  15 October           7368539        87.55%
# 260  16 October           7430841        87.77%

# %% [markdown]
# ## 4. Latest - State wise

# %%
## https://api.covid19india.org/csv/latest/state_wise.csv
    
# read data
latest = pd.read_csv('https://api.covid19india.org/csv/latest/state_wise.csv')
# save as a .csv file`
latest.to_csv('state_level_latest.csv', index=False)

df= latest.sort_values(['State']) 

df.drop(["State_Notes",'State_code'],axis=1,inplace=True)
# first few rows
df.iloc[1: 38]
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 2                             Andhra Pradesh     775470     730109    6382
# 28                         Arunachal Pradesh      12971       9889      30
# 12                                     Assam     199749     170263     853
# 11                                     Bihar     201887     190256     981
# 27                                Chandigarh      13532      12352     206
# 16                              Chhattisgarh     155987     126869    1425
# 34  Dadra and Nagar Haveli and Daman and Diu       3174       3084       2
# 6                                      Delhi     324459     295699    5946
# 22                                       Goa      40091      35610     531
# 14                                   Gujarat     157474     139249    3620
# 17                                   Haryana     147933     135858    1634
# 25                          Himachal Pradesh      18522      15586     257
# 20                         Jammu and Kashmir      86754      76479    1366
# 19                                 Jharkhand      95425      88058     824
# 3                                  Karnataka     751390     628588   10356
# 7                                     Kerala     325213     228998    1114
# 31                                    Ladakh       5441       4461      65
# 37                               Lakshadweep          0          0       0
# 15                            Madhya Pradesh     157936     141273    2735
# 1                                Maharashtra    1576062    1344368   41502
# 26                                   Manipur      14715      11245     109
# 29                                 Meghalaya       8303       5736      75
# 35                                   Mizoram       2245       2133       0
# 30                                  Nagaland       7604       6051      17
# 9                                     Odisha     266345     241385    1174
# 23                                Puducherry      32766      27671     571
# 18                                    Punjab     126737     116165    3980
# 13                                 Rajasthan     169289     146185    1723
# 33                                    Sikkim       3531       3096      59
# 36                          State Unassigned          0          0       0
# 4                                 Tamil Nadu     679191     627703   10532
# 10                                 Telangana     220675     196636    1265
# 0                                      Total    7434432    6523893  113062
# 24                                   Tripura      29324      26012     323
# 5                              Uttar Pradesh     449935     408083    6589
# 21                               Uttarakhand      57042      50155     829
# 8                                West Bengal     313188     274757    5931
#
#     Active    Last_Updated_Time  Migrated_Other  Delta_Confirmed  \
# 2    38979  16/10/2020 20:07:29               0                0
# 28    3052  16/10/2020 09:34:26               0                0
# 12   28630  17/10/2020 00:39:25               3                0
# 11   10649  16/10/2020 19:10:30               1                0
# 27     974  17/10/2020 00:39:29               0                0
# 16   27693  16/10/2020 21:40:26               0                0
# 34      63  16/10/2020 20:39:33              25                0
# 6    22814  16/10/2020 20:07:31               0                0
# 22    3950  16/10/2020 23:15:49               0                0
# 14   14605  16/10/2020 21:23:29               0                0
# 17   10441  16/10/2020 20:07:36               0                0
# 25    2642  16/10/2020 22:47:26              37                0
# 20    8909  16/10/2020 19:40:39               0                0
# 19    6543  17/10/2020 08:46:26               0                0
# 3   112427  16/10/2020 22:33:26              19                0
# 7    95009  16/10/2020 20:07:32              92                0
# 31     915  16/10/2020 21:40:37               0                0
# 37       0  26/03/2020 07:19:29               0                0
# 15   13928  16/10/2020 20:57:28               0                0
# 1   189715  16/10/2020 23:15:47             477                0
# 26    3361  16/10/2020 20:07:38               0                0
# 29    2492  16/10/2020 21:58:28               0                0
# 35     112  17/10/2020 10:36:24               0               16
# 30    1466  16/10/2020 20:07:40              70                0
# 9    23786  17/10/2020 12:15:23               0             2196
# 23    4524  16/10/2020 21:06:27               0                0
# 18    6592  16/10/2020 20:57:29               0                0
# 13   21381  16/10/2020 19:23:28               0                0
# 33     295  17/10/2020 00:39:31              81                0
# 36       0  19/07/2020 09:40:01               0                0
# 4    40956  16/10/2020 18:37:24               0                0
# 10   22774  17/10/2020 11:15:23               0             1451
# 0   796283  17/10/2020 12:15:21            1194             3797
# 24    2966  17/10/2020 09:56:23              23              134
# 5    35263  16/10/2020 19:40:31               0                0
# 21    5692  17/10/2020 00:39:27             366                0
# 8    32500  16/10/2020 20:39:28               0                0
#
#     Delta_Recovered  Delta_Deaths
# 2                 0             0
# 28                0             0
# 12                0             0
# 11                0             0
# 27                0             0
# 16                0             0
# 34                0             0
# 6                 0             0
# 22                0             0
# 14                0             0
# 17                0             0
# 25                0             0
# 20                0             0
# 19                0             0
# 3                 0             0
# 7                 0             0
# 31                0             0
# 37                0             0
# 15                0             0
# 1                 0             0
# 26                0             0
# 29                0             0
# 35                6             0
# 30                0             0
# 9                 0            17
# 23                0             0
# 18                0             0
# 13                0             0
# 33                0             0
# 36                0             0
# 4                 0             0
# 10             1983             9
# 0              2259            29
# 24              270             3
# 5                 0             0
# 21                0             0
# 8                 0             0

# %% [markdown]
# ## 5. Top 5 effected state

# %%
df.sort_index().iloc[1:6]
# Out:
#             State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 1     Maharashtra    1576062    1344368   41502  189715  16/10/2020 23:15:47
# 2  Andhra Pradesh     775470     730109    6382   38979  16/10/2020 20:07:29
# 3       Karnataka     751390     628588   10356  112427  16/10/2020 22:33:26
# 4      Tamil Nadu     679191     627703   10532   40956  16/10/2020 18:37:24
# 5   Uttar Pradesh     449935     408083    6589   35263  16/10/2020 19:40:31
#
#    Migrated_Other  Delta_Confirmed  Delta_Recovered  Delta_Deaths
# 1             477                0                0             0
# 2               0                0                0             0
# 3              19                0                0             0
# 4               0                0                0             0
# 5               0                0                0             0

# %% [markdown]
# ## 6. daily state wise data

# %%
# read data
state_wise_daily = pd.read_csv('https://api.covid19india.org/csv/latest/state_wise_daily.csv')

# melt dataframe
state_wise_daily = state_wise_daily.melt(id_vars=['Date', 'Status'], 
                                         value_vars=state_wise_daily.columns[2:], 
                                         var_name='State', value_name='Count')

# pivot table
state_wise_daily = state_wise_daily.pivot_table(index=['Date', 'State'], 
                                                columns=['Status'], 
                                                values='Count').reset_index()

# map state names to state codes
state_codes = {code:state for code, state in zip(latest['State_code'], latest['State'])}
state_codes['DD'] = 'Daman and Diu'
state_wise_daily['State_Name'] = state_wise_daily['State'].map(state_codes)


# save as a .csv file
state_wise_daily.to_csv('state_level_daily.csv')

# last 39 rows 
state_wise_daily.tail(39)
# Out:
# Status       Date State  Confirmed  Deceased  Recovered  \
# 8424    31-May-20    AN          0         0          0
# 8425    31-May-20    AP        110         2         51
# 8426    31-May-20    AR          0         0          0
# 8427    31-May-20    AS        123         0         22
# 8428    31-May-20    BR        242         2        209
# 8429    31-May-20    CH          4         0          0
# 8430    31-May-20    CT         51         0         12
# 8431    31-May-20    DD          0         0          0
# 8432    31-May-20    DL       1295        57        403
# 8433    31-May-20    DN          0         0          0
# 8434    31-May-20    GA          1         0          2
# 8435    31-May-20    GJ        438        31        689
# 8436    31-May-20    HP         18         0          9
# 8437    31-May-20    HR        168         0         77
# 8438    31-May-20    JH         41         0          0
# 8439    31-May-20    JK        105         0         19
# 8440    31-May-20    KA        299         2        221
# 8441    31-May-20    KL         61         0         15
# 8442    31-May-20    LA          0         0          4
# 8443    31-May-20    LD          0         0          0
# 8444    31-May-20    MH       2487        89       1248
# 8445    31-May-20    ML          0         0          0
# 8446    31-May-20    MN         11         0          5
# 8447    31-May-20    MP        198         7        398
# 8448    31-May-20    MZ          0         0          0
# 8449    31-May-20    NL          7         0          0
# 8450    31-May-20    OR        129         0         76
# 8451    31-May-20    PB         30         1         20
# 8452    31-May-20    PY         13         0          2
# 8453    31-May-20    RJ        214         1        293
# 8454    31-May-20    SK          0         0          0
# 8455    31-May-20    TG        199         5         16
# 8456    31-May-20    TN       1149        13        757
# 8457    31-May-20    TR         45         0          1
# 8458    31-May-20    TT       8789       222       4928
# 8459    31-May-20    UN        448         0          0
# 8460    31-May-20    UP        374         4        192
# 8461    31-May-20    UT        158         0          0
# 8462    31-May-20    WB        371         8        187
#
# Status                                State_Name
# 8424                 Andaman and Nicobar Islands
# 8425                              Andhra Pradesh
# 8426                           Arunachal Pradesh
# 8427                                       Assam
# 8428                                       Bihar
# 8429                                  Chandigarh
# 8430                                Chhattisgarh
# 8431                               Daman and Diu
# 8432                                       Delhi
# 8433    Dadra and Nagar Haveli and Daman and Diu
# 8434                                         Goa
# 8435                                     Gujarat
# 8436                            Himachal Pradesh
# 8437                                     Haryana
# 8438                                   Jharkhand
# 8439                           Jammu and Kashmir
# 8440                                   Karnataka
# 8441                                      Kerala
# 8442                                      Ladakh
# 8443                                 Lakshadweep
# 8444                                 Maharashtra
# 8445                                   Meghalaya
# 8446                                     Manipur
# 8447                              Madhya Pradesh
# 8448                                     Mizoram
# 8449                                    Nagaland
# 8450                                      Odisha
# 8451                                      Punjab
# 8452                                  Puducherry
# 8453                                   Rajasthan
# 8454                                      Sikkim
# 8455                                   Telangana
# 8456                                  Tamil Nadu
# 8457                                     Tripura
# 8458                                       Total
# 8459                            State Unassigned
# 8460                               Uttar Pradesh
# 8461                                 Uttarakhand
# 8462                                 West Bengal

# %% [markdown]
# ## 7.  District wise distribution

# %%
# read data
district_wise = pd.read_csv('https://api.covid19india.org/csv/latest/district_wise.csv')

# save as .csv file
district_wise.to_csv('district_level_latest.csv', index=False)

df =district_wise.sort_values(['State','District'])
df.drop(["District_Notes",'State_Code','District_Key'],axis=1,inplace=True)

# first few rows
df.head()
# Out:
#      SlNo                        State                  District  Confirmed  \
# 1       1  Andaman and Nicobar Islands                  Nicobars          0
# 2       2  Andaman and Nicobar Islands  North and Middle Andaman          1
# 3       3  Andaman and Nicobar Islands             South Andaman         51
# 765   728  Andaman and Nicobar Islands                   Unknown       4020
# 5       4               Andhra Pradesh                 Anantapur      62075
#
#      Active  Recovered  Deceased  Migrated_Other  Delta_Confirmed  \
# 1         0          0         0               0                0
# 2         0          1         0               0                0
# 3        19         32         0               0                0
# 765     166       3798        56               0                0
# 5      1932      59610       533               0                0
#
#      Delta_Active  Delta_Recovered  Delta_Deceased  Last_Updated
# 1               0                0               0           NaN
# 2               0                0               0           NaN
# 3               0                0               0           NaN
# 765             0                0               0           NaN
# 5               0                0               0           NaN

# %% [markdown]
# ## 8. most effected district

# %%
df= df.sort_values(['Confirmed'],ascending=False) 
df[['State','District','Confirmed']].iloc[1]
# Out:
# State        Maharashtra
# District            Pune
# Confirmed         321858
# Name: 356, dtype: object

# %% [markdown]
# ## 9. Total Sample Tested

# %%
# read data
tests_day_wise = pd.read_csv('https://api.covid19india.org/csv/latest/tested_numbers_icmr_data.csv')

# save as .csv file
tests_day_wise.to_csv('tests_day_wise.csv', index=False)
df=tests_day_wise
df.drop(["Source",'Source 1','Source 3'],axis=1,inplace=True)
#total samples tested
int(df['Total Samples Tested'].iloc[-1])
# Out:
# 93254017

# %% [markdown]
# ## 10. Top 5 State with heighest tests no.

# %%
# read data
tests_state_wise = pd.read_csv('https://api.covid19india.org/csv/latest/statewise_tested_numbers_data.csv')

# save as .csv file
tests_state_wise.to_csv('tests_state_wise.csv', index=False)

df=tests_state_wise.sort_values(['Total Tested'],ascending=False)
df=df.loc[df['Updated On'] == '16/10/2020']
#df.drop(['RT PCR Tests','Antigen Tests','Other Tests','Tag (Total Tested)'],axis=1,inplace=True)
# top 5 rows
df[['Updated On','State','Total Tested']].head(5)
# Out:
#       Updated On           State  Total Tested
# 5981  16/10/2020   Uttar Pradesh    12679476.0
# 898   16/10/2020           Bihar     8894758.0
# 5488  16/10/2020      Tamil Nadu     8766038.0
# 3691  16/10/2020     Maharashtra     7989693.0
# 346   16/10/2020  Andhra Pradesh     6920377.0

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=day_wise.T

df.loc["Total Deceased"].plot()
df.loc["Total Confirmed"].plot()
df.loc["Total Recovered"].plot()
plt.legend()

plt.plot()
# Out:
# []
